# %% [markdown]
# <a href="https://colab.research.google.com/github/Nancy-Batra/Flyrank-ML-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Nancy-Batra/Flyrank-ML-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ## My Lane: Refresh / Content Opportunity Scoring
#
# I chose **Lane 2: Refresh / Content Opportunity Scoring** because the goal is to support content decisions by ranking pages that need attention and it combines data analysis and machine learning to solve a practical problem while using transparent and explainable methods.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Decision:** The decision my work focuses on is which content pages should be reviewed first for refresh?
#
# **Who acts on it?**: The content team or SEO. They review and update the highest priority pages first.
#
# **Cost of a wrong recommendation:**: If a low priority page is recommended, time and efforts will be wasted and if an important page is missed, it may continue losing visibility and traffic.
#
# **Why machine learning?**: Many signals such as impressions, CTR, average position, content age, and freshness contribute to page performance. Machine learning can combine these signals to rank pages more effectively than a simple manual rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Total pages:", len(df))
print("Average impressions:", round(df["impressions_90d"].mean(),2))
print("Average CTR:", round(df["ctr"].mean(),2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_681/818340673.py in <cell line: 0>()
#       1 import pandas as pd, numpy as np
# ----> 2 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       3 print(df.shape[0], "rows,", df.shape[1], "columns")
#       4 df.head(3)
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
